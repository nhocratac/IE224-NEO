# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/NASA Near-Earth Objects-CleanbyThang.csv')

df.head()
# Out:
#         id  absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0  2001981                 15.22                               True
# 1  2002059                 15.97                              False
# 2  2002061                 16.36                              False
# 3  2002062                 17.10                              False
# 4  2002063                 17.28                              False
#
#    is_sentry_object  kilometers_estimated_diameter_min  \
# 0             False                           2.401900
# 1             False                           1.700415
# 2             False                           1.420872
# 3             False                           1.010543
# 4             False                           0.930154
#
#    kilometers_estimated_diameter_max orbit_class_type  perihelion_distance  \
# 0                           5.370812              APO             0.621512
# ...

# %%
df['is_potentially_hazardous_asteroid'] = df['is_potentially_hazardous_asteroid'].astype(int)

# %%
df['is_potentially_hazardous_asteroid'].value_counts()
# Out:
# is_potentially_hazardous_asteroid
# 0    21906
# 1     2094
# Name: count, dtype: int64

# %%
# Out:
# Các biến có tương quan mạnh với biến is_potentially_hazardous_asteroid:
# is_potentially_hazardous_asteroid    1.000000
# kilometers_estimated_diameter_max    0.175060
# kilometers_estimated_diameter_min    0.175060
# aphelion_distance                    0.009947
# id                                  -0.058072
# perihelion_distance                 -0.206415
# absolute_magnitude_h                -0.298178
# Name: is_potentially_hazardous_asteroid, dtype: float64

# %%
features = ['absolute_magnitude_h', 'estimated_diameter_min_km', 
            'estimated_diameter_max_km', 'relative_velocity_km_per_h', 
            'miss_distance_km', 'orbit_class_type', 
            'absolute_magnitude_h', 'estimated_diameter_min_km', 
            'estimated_diameter_max_km', 'relative_velocity_km_per_h', 
            'miss_distance_km', 'orbit_class_type', 
            'absolute_magnitude_h', 'estimated_diameter_min_km', 
            'estimated_diameter_max_km', 'relative_velocity_km_per_h', 
            'miss_distance_km', 'orbit_class_type']
