# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/NASA Near-Earth Objects-CleanbyThang.csv')

df.head()
# Out:
#         id  absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0  2001981                 15.22                               True
# 1  2002059                 15.97                              False
# 2  2002061                 16.36                              False
# 3  2002062                 17.10                              False
# 4  2002063                 17.28                              False
#
#    is_sentry_object  kilometers_estimated_diameter_min  \
# 0             False                           2.401900
# 1             False                           1.700415
# 2             False                           1.420872
# 3             False                           1.010543
# 4             False                           0.930154
#
#    kilometers_estimated_diameter_max orbit_class_type  perihelion_distance  \
# 0                           5.370812              APO             0.621512
# ...

# %%
missing_values = [".", "?", "_", "-", "", "None", "NULL", "Not", "|", np.nan]
for value in missing_values:
    print("Number of missing values: ",df.isin([value]).sum().sum(), " for ", value)
# Out:
# Number of missing values:  0  for  .
# Number of missing values:  0  for  ?
# Number of missing values:  0  for  _
# Number of missing values:  0  for  -
# Number of missing values:  0  for
# Number of missing values:  0  for  None
# Number of missing values:  0  for  NULL
# Number of missing values:  0  for  Not
# Number of missing values:  0  for  |
# Number of missing values:  0  for  nan
