# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../../data/NASA Near-Earth Objects-Sampling.csv', index_col=0)
df.index = range(1, len(df) + 1) 

df.head()
# Out:
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  is_sentry_object  \
# 1                 15.22                               True             False
# 2                 15.97                              False             False
# 3                 16.36                              False             False
# 4                 17.10                              False             False
# 5                 17.28                              False             False
#
#    kilometers_estimated_diameter_min  kilometers_estimated_diameter_max  \
# 1                           2.401900                           5.370812
# 2                           1.700415                           3.802244
# 3                           1.420872                           3.177167
# 4                           1.010543                           2.259644
# 5                           0.930154                           2.079888
#
#   orbit_class_type  perihelion_distance  aphelion_distance  \
# 1              APO             0.621512           2.931360
# 2              AMO             1.238537           4.047945
# 3              AMO             1.050403           3.478155
# 4              ATE             0.790185           1.143633
# 5              APO             0.701397           1.454804
#
#   first_observation_date last_observation_date  \
# 1             1973-03-06            2021-10-20
# 2             1963-10-16            2021-04-15
# 3             1960-10-22            2021-06-12
# 4             1955-12-17            2019-11-10
# 5             1977-04-24            2021-12-02
#
#                              orbit_class_description  first_observation_year  \
# 1  Near-Earth asteroid orbits which cross the Ear...                      19
# 2  Near-Earth asteroid orbits similar to that of ...                      14
# 3  Near-Earth asteroid orbits similar to that of ...                      13
# 4  Near-Earth asteroid orbits similar to that of ...                      10
# 5  Near-Earth asteroid orbits which cross the Ear...                      23
#
#    last_observation_year  is_collidable
# 1                     32           True
# 2                     32          False
# 3                     32          False
# 4                     30           True
# 5                     32           True

# %%
df['first_observation_date'] = pd.to_datetime(df['first_observation_date'])
df['last_observation_date'] = pd.to_datetime(df['last_observation_date'])

# %%
df = df[~((df['last_observation_date'].dt.year < 2021) & (df['is_potentially_hazardous_asteroid'] == False))]
df.head()
# Out:
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  is_sentry_object  \
# 1                 15.22                               True             False
# 2                 15.97                              False             False
# 3                 16.36                              False             False
# 5                 17.28                              False             False
# 6                 16.23                              False             False
#
#    kilometers_estimated_diameter_min  kilometers_estimated_diameter_max  \
# 1                           2.401900                           5.370812
# 2                           1.700415                           3.802244
# 3                           1.420872                           3.177167
# 5                           0.930154                           2.079888
# 6                           1.508534                           3.373184
#
#   orbit_class_type  perihelion_distance  aphelion_distance  \
# 1              APO             0.621512           2.931360
# 2              AMO             1.238537           4.047945
# 3              AMO             1.050403           3.478155
# 5              APO             0.701397           1.454804
# 6              ATE             0.468751           1.195322
#
#   first_observation_date last_observation_date  \
# 1             1973-03-06            2021-10-20
# 2             1963-10-16            2021-04-15
# 3             1960-10-22            2021-06-12
# 5             1977-04-24            2021-12-02
# 6             1975-10-03            2021-12-02
#
#                              orbit_class_description  first_observation_year  \
# 1  Near-Earth asteroid orbits which cross the Ear...                      19
# 2  Near-Earth asteroid orbits similar to that of ...                      14
# 3  Near-Earth asteroid orbits similar to that of ...                      13
# 5  Near-Earth asteroid orbits which cross the Ear...                      23
# 6  Near-Earth asteroid orbits similar to that of ...                      21
#
#    last_observation_year  is_collidable
# 1                     32           True
# 2                     32          False
# 3                     32          False
# 5                     32           True
# 6                     32           True

# %%
filename = '../../data/NASA Near-Earth Objects-Train.csv'
df.to_csv(filename)
